# %%
#Loading pandas 
import pandas as pd

# %%
#Importing the dataset
Test_file = pd.read_csv('/Users/habeeblanlokun/Downloads/BasicCompanyData-2023-07-01-part7_7.csv')
# Out:
# /var/folders/6n/n4gr66kx2857m_7brpxjd2n00000gn/T/ipykernel_96145/1620570857.py:2: DtypeWarning: Columns (43,44,45,46,47,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   Test_file = pd.read_csv('/Users/habeeblanlokun/Downloads/BasicCompanyData-2023-07-01-part7_7.csv')

# %%
#Checking out the dataset
Test_file.head()
# Out:
#                                      CompanyName  CompanyNumber  \
# 0                                VISION PACK LTD       10831327
# 1                  VISION PAINT & DESIGN LIMITED       05628705
# 2                  VISION PAINT SPRAYING LIMITED       10947174
# 3                             VISION PARATUS LTD       14906975
# 4  VISION PARK CYGNET MANAGEMENT COMPANY LIMITED       05747663
#
#   RegAddress.CareOf RegAddress.POBox  \
# 0               NaN              NaN
# 1               NaN              NaN
# 2               NaN              NaN
# 3               NaN              NaN
# 4               NaN              NaN
#
#                     RegAddress.AddressLine1  RegAddress.AddressLine2  \
# 0                          6-8 MANVERS ROAD              SWALLOWNEST
# 1                          9 FAIRLOP AVENUE                      NaN
# 2               UNIT 4F MANOR BUSINESS PARK           WOODFORD HALSE
# 3                      71-75 SHELTON STREET            COVENT GARDEN
# ...

# %%
#Checking the columns of in the dataset
#list(Test_file)
Test_file.columns
# Out:
# Index(['CompanyName', ' CompanyNumber', 'RegAddress.CareOf',
#        'RegAddress.POBox', 'RegAddress.AddressLine1',
#        ' RegAddress.AddressLine2', 'RegAddress.PostTown', 'RegAddress.County',
#        'RegAddress.Country', 'RegAddress.PostCode', 'CompanyCategory',
#        'CompanyStatus', 'CountryOfOrigin', 'DissolutionDate',
#        'IncorporationDate', 'Accounts.AccountRefDay',
#        'Accounts.AccountRefMonth', 'Accounts.NextDueDate',
#        'Accounts.LastMadeUpDate', 'Accounts.AccountCategory',
#        'Returns.NextDueDate', 'Returns.LastMadeUpDate',
#        'Mortgages.NumMortCharges', 'Mortgages.NumMortOutstanding',
#        'Mortgages.NumMortPartSatisfied', 'Mortgages.NumMortSatisfied',
#        'SICCode.SicText_1', 'SICCode.SicText_2', 'SICCode.SicText_3',
#        'SICCode.SicText_4', 'LimitedPartnerships.NumGenPartners',
#        'LimitedPartnerships.NumLimPartners', 'URI', 'PreviousName_1.CONDATE',
# ...

# %%
#Filtering the dataset for Company category that is 'Private limited company'
Test1= filtered_Test_file = Test_file[Test_file['CompanyCategory']== 'Private Limited Company']
(Test1)
# Out:
#                            CompanyName  CompanyNumber RegAddress.CareOf  \
# 0                      VISION PACK LTD       10831327               NaN
# 1        VISION PAINT & DESIGN LIMITED       05628705               NaN
# 2        VISION PAINT SPRAYING LIMITED       10947174               NaN
# 3                   VISION PARATUS LTD       14906975               NaN
# 5       VISION PARK MANAGEMENT LIMITED       02479238               NaN
# ...                                ...            ...               ...
# 259633    “THE GREENHOUSE” COMPANY LTD       11457383               NaN
# 259634   “THE SKULL” SAUCE COMPANY LTD       SC660098               NaN
# 259635           “UGUR-97” FIRMASI LTD       13707057               NaN
# 259636             € RECYCLING LIMITED       04528854               NaN
# 259637            €URO IMPORTS LIMITED       08182582               NaN
#
#        RegAddress.POBox      RegAddress.AddressLine1  RegAddress.AddressLine2  \
# ...

# %%
#Filtering the dataset for Company status that is 'Active'
Test2= filtered_Test_file = Test_file[Test_file['CompanyStatus']== 'Active']
Test2
# Out:
#                                           CompanyName  CompanyNumber  \
# 0                                     VISION PACK LTD       10831327
# 1                       VISION PAINT & DESIGN LIMITED       05628705
# 3                                  VISION PARATUS LTD       14906975
# 4       VISION PARK CYGNET MANAGEMENT COMPANY LIMITED       05747663
# 5                      VISION PARK MANAGEMENT LIMITED       02479238
# ...                                               ...            ...
# 259632                “SAIL IN GREECE ADVENTURES” LTD       09511422
# 259633                   “THE GREENHOUSE” COMPANY LTD       11457383
# 259635                          “UGUR-97” FIRMASI LTD       13707057
# 259636                            € RECYCLING LIMITED       04528854
# 259637                           €URO IMPORTS LIMITED       08182582
#
#        RegAddress.CareOf RegAddress.POBox  \
# 0                    NaN              NaN
# 1                    NaN              NaN
# ...

# %%
#Filtering the dataset for Account category that is 'Small and Medium'
Test3= filtered_Test_file = Test_file[(Test_file['Accounts.AccountCategory']== 'SMALL') & (Test_file['Accounts.AccountCategory'] == 'MEDIUM')]
Test3
# Out:
# Empty DataFrame
# ...

# %%
#Saving each of the data query to csv files
Test1.to_csv('/Users/habeeblanlokun/Downloads/Test1.csv', index=False)
Test2.to_csv('/Users/habeeblanlokun/Downloads/Test2.csv', index=False)
Test3.to_csv('/Users/habeeblanlokun/Downloads/Test3.csv', index=False)
